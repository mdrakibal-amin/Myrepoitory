# %% [markdown]
# # EDA->Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# for showing the figures in the notebook itself
# %matplotlib inline

# %%
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)

# %%
df = pd.read_csv("https://raw.githubusercontent.com/jasimdipu/forwordit_datascience_batch_16/main/eda/FIFA_data.csv")
df.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
df.tail()
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 18202  https://cdn.sofifa.org/players/4/19/238813.png     England
# 18203  https://cdn.sofifa.org/players/4/19/243165.png      Sweden
# 18204  https://cdn.sofifa.org/players/4/19/241638.png     England
# 18205  https://cdn.sofifa.org/players/4/19/246268.png     England
# 18206  https://cdn.sofifa.org/players/4/19/246269.png     England
#
#                                       Flag  Overall  Potential  \
# 18202  https://cdn.sofifa.org/flags/14.png       47         65
# 18203  https://cdn.sofifa.org/flags/46.png       47         63
# 18204  https://cdn.sofifa.org/flags/14.png       47         67
# ...

# %% [markdown]
# # Data Analysis

# %%
df.drop('Unnamed: 0',axis=1, inplace=True)

# %%
df.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
# ...

# %%
df.shape
# Out:
# (18207, 88)

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 88 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        18207 non-null  int64
#  1   Name                      18207 non-null  object
#  2   Age                       18207 non-null  int64
#  3   Photo                     18207 non-null  object
#  4   Nationality               18207 non-null  object
#  5   Flag                      18207 non-null  object
#  6   Overall                   18207 non-null  int64
#  7   Potential                 18207 non-null  int64
#  8   Club                      17966 non-null  object
#  9   Club Logo                 18207 non-null  object
#  10  Value                     18207 non-null  object
#  11  Wage                      18207 non-null  object
#  12  Special                   18207 non-null  int64
# ...

# %%
df.isna().sum()
# Out:
# ID                              0
# Name                            0
# Age                             0
# Photo                           0
# Nationality                     0
# Flag                            0
# Overall                         0
# Potential                       0
# Club                          241
# Club Logo                       0
# Value                           0
# Wage                            0
# Special                         0
# Preferred Foot                 48
# International Reputation       48
# Weak Foot                      48
# Skill Moves                    48
# Work Rate                      48
# Body Type                      48
# Real Face                      48
# Position                       60
# Jersey Number                  60
# Joined                       1553
# Loaned From                 16943
# Contract Valid Until          289
# Height                         48
# Weight                         48
# ...

# %%
df.isna().sum().plot(kind='bar',figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
f, ax = plt.subplots(figsize=(25,20))
sns.heatmap(df.corr(),annot=True, linewidths=0.5, linecolor='red',fmt='.2f',ax=ax)
plt.show()

# %%
# !pip install wordcloud

# %%
from wordcloud import WordCloud

# %%
plt.subplots(figsize=(20, 20))
wordcloud = WordCloud(
    background_color='white',
    width=1920,
    height=1080
).generate("".join(df.Nationality))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# # Feature Engineering

# %%
df['Club'].fillna('No Club',inplace=True)

# %%
df['Club'].isna().sum()
# Out:
# 0

# %%
df['Position'].isna().sum()
# Out:
# 60

# %%
df['Position'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         RF
# 1         ST
# 2         LW
# 3         GK
# 4        RCM
# 5         LF
# 6        RCM
# 7         RS
# 8        RCB
# 9         GK
# 10        ST
# 11       LCM
# 12        CB
# 13       LCM
# 14       LDM
# 15        LF
# 16        ST
# 17       CAM
# 18        GK
# 19        GK
# 20       CDM
# 21        LS
# 22        GK
# 23        ST
# 24       LCB
# 25        RM
# 26        RM
# 27       CDM
# 28       LAM
# 29        LW
# 30        LW
# 31       CAM
# 32        LW
# 33        LM
# 34       LCB
# 35        LB
# 36        ST
# 37        GK
# 38        LS
# 39       RCB
# 40        GK
# 41        GK
# 42        CB
# 43        ST
# 44       LCB
# 45       RDM
# 46        GK
# 47        ST
# 48        ST
# 49        LB
# 50        RF
# 51       LCB
# 52       LCM
# 53       RCM
# 54       RCB
# 55        LW
# 56        RW
# 57        GK
# 58        LM
# 59       LCB
# 60        RW
# 61       CAM
# 62       RCB
# ...

# %%
df['Position'].fillna('ST',inplace=True)

# %%
df['Position'].isna().sum()
# Out:
# 0

# %%
df['Position'].fillna('LDM',inplace=True)

# %%
df['Position'].isna().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# ID                            int64
# Name                         object
# Age                           int64
# Photo                        object
# Nationality                  object
# Flag                         object
# Overall                       int64
# Potential                     int64
# Club                         object
# Club Logo                    object
# Value                        object
# Wage                         object
# Special                       int64
# Preferred Foot               object
# International Reputation    float64
# Weak Foot                   float64
# Skill Moves                 float64
# Work Rate                    object
# Body Type                    object
# Real Face                    object
# Position                     object
# Jersey Number               float64
# Joined                       object
# Loaned From                  object
# Contract Valid Until         object
# Height                       object
# ...

# %%
# continuous float value:
con_f_val = []
for i, j in df.dtypes.items():
    if j == float:
        con_f_val.append(i)
con_f_val
# Out:
# ['International Reputation',
#  'Weak Foot',
#  'Skill Moves',
#  'Jersey Number',
#  'Crossing',
#  'Finishing',
#  'HeadingAccuracy',
#  'ShortPassing',
#  'Volleys',
#  'Dribbling',
#  'Curve',
#  'FKAccuracy',
#  'LongPassing',
#  'BallControl',
#  'Acceleration',
#  'SprintSpeed',
#  'Agility',
#  'Reactions',
#  'Balance',
#  'ShotPower',
#  'Jumping',
#  'Stamina',
#  'Strength',
#  'LongShots',
#  'Aggression',
#  'Interceptions',
#  'Positioning',
#  'Vision',
#  'Penalties',
#  'Composure',
#  'Marking',
#  'StandingTackle',
#  'SlidingTackle',
#  'GKDiving',
#  'GKHandling',
#  'GKKicking',
#  'GKPositioning',
#  'GKReflexes']

# %%
for i in con_f_val:
    print(i, "=>",df[i].isna().sum())
# Out:
# International Reputation => 48
# Weak Foot => 48
# Skill Moves => 48
# Jersey Number => 60
# Crossing => 48
# Finishing => 48
# HeadingAccuracy => 48
# ShortPassing => 48
# Volleys => 48
# Dribbling => 48
# Curve => 48
# FKAccuracy => 48
# LongPassing => 48
# BallControl => 48
# Acceleration => 48
# SprintSpeed => 48
# Agility => 48
# Reactions => 48
# Balance => 48
# ShotPower => 48
# Jumping => 48
# Stamina => 48
# Strength => 48
# LongShots => 48
# Aggression => 48
# Interceptions => 48
# Positioning => 48
# Vision => 48
# Penalties => 48
# Composure => 48
# Marking => 48
# StandingTackle => 48
# SlidingTackle => 48
# GKDiving => 48
# GKHandling => 48
# GKKicking => 48
# GKPositioning => 48
# GKReflexes => 48

# %%
for i in con_f_val:
    df[i].fillna(df[i].mean(), inplace=True)

# %%
for i in con_f_val:
    print(i,"=>",df[i].isna().sum())
# Out:
# International Reputation => 0
# Weak Foot => 0
# Skill Moves => 0
# Jersey Number => 0
# Crossing => 0
# Finishing => 0
# HeadingAccuracy => 0
# ShortPassing => 0
# Volleys => 0
# Dribbling => 0
# Curve => 0
# FKAccuracy => 0
# LongPassing => 0
# BallControl => 0
# Acceleration => 0
# SprintSpeed => 0
# Agility => 0
# Reactions => 0
# Balance => 0
# ShotPower => 0
# Jumping => 0
# Stamina => 0
# Strength => 0
# LongShots => 0
# Aggression => 0
# Interceptions => 0
# Positioning => 0
# Vision => 0
# Penalties => 0
# Composure => 0
# Marking => 0
# StandingTackle => 0
# SlidingTackle => 0
# GKDiving => 0
# GKHandling => 0
# GKKicking => 0
# GKPositioning => 0
# GKReflexes => 0

# %%
con_i_val = df.columns

# %%
con_i_val
# Out:
# Index(['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
con_i_val = []
for i, j in df.dtypes.items():
    if j == int:
        con_i_val.append(i)
con_i_val
# Out:
# []

# %%
df.dtypes
# Out:
# ID                            int64
# Name                         object
# Age                           int64
# Photo                        object
# Nationality                  object
# Flag                         object
# Overall                       int64
# Potential                     int64
# Club                         object
# Club Logo                    object
# Value                        object
# Wage                         object
# Special                       int64
# Preferred Foot               object
# International Reputation    float64
# Weak Foot                   float64
# Skill Moves                 float64
# Work Rate                    object
# Body Type                    object
# Real Face                    object
# Position                     object
# Jersey Number               float64
# Joined                       object
# Loaned From                  object
# Contract Valid Until         object
# Height                       object
# ...

# %%
con_i_val = []
for i, j in df.dtypes.items():
    if j != float:
        con_i_val.append(i)
con_i_val
# Out:
# ['ID',
#  'Name',
#  'Age',
#  'Photo',
#  'Nationality',
#  'Flag',
#  'Overall',
#  'Potential',
#  'Club',
#  'Club Logo',
#  'Value',
#  'Wage',
#  'Special',
#  'Preferred Foot',
#  'Work Rate',
#  'Body Type',
#  'Real Face',
#  'Position',
#  'Joined',
#  'Loaned From',
#  'Contract Valid Until',
#  'Height',
#  'Weight',
#  'LS',
#  'ST',
#  'RS',
#  'LW',
#  'LF',
#  'CF',
#  'RF',
#  'RW',
#  'LAM',
#  'CAM',
#  'RAM',
#  'LM',
#  'LCM',
#  'CM',
#  'RCM',
#  'RM',
#  'LWB',
#  'LDM',
#  'CDM',
#  'RDM',
#  'RWB',
#  'LB',
#  'LCB',
#  'CB',
#  'RCB',
#  'RB',
#  'Release Clause']

# %%
for i in con_i_val:
    df[i].fillna(df[i].mode()[0],inplace=True)

# %%
df.isna().sum()
# Out:
# ID                          0
# Name                        0
# Age                         0
# Photo                       0
# Nationality                 0
# Flag                        0
# Overall                     0
# Potential                   0
# Club                        0
# Club Logo                   0
# Value                       0
# Wage                        0
# Special                     0
# Preferred Foot              0
# International Reputation    0
# Weak Foot                   0
# Skill Moves                 0
# Work Rate                   0
# Body Type                   0
# Real Face                   0
# Position                    0
# Jersey Number               0
# Joined                      0
# Loaned From                 0
# Contract Valid Until        0
# Height                      0
# Weight                      0
# LS                          0
# ST                          0
# RS                          0
# LW                          0
# ...

# %%
df.isna().sum().plot(kind='bar',figsize=(20,8))
# Out:
# <AxesSubplot:>

# %%
df.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
# ...

# %%
df.tail()
# Out:
#            ID                Name  Age  \
# 18202  238813        J. Lundstram   19
# 18203  243165  N. Christoffersson   19
# 18204  241638           B. Worman   16
# 18205  246268      D. Walker-Rice   17
# 18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 18202  https://cdn.sofifa.org/players/4/19/238813.png     England
# 18203  https://cdn.sofifa.org/players/4/19/243165.png      Sweden
# 18204  https://cdn.sofifa.org/players/4/19/241638.png     England
# 18205  https://cdn.sofifa.org/players/4/19/246268.png     England
# 18206  https://cdn.sofifa.org/players/4/19/246269.png     England
#
#                                       Flag  Overall  Potential  \
# 18202  https://cdn.sofifa.org/flags/14.png       47         65
# 18203  https://cdn.sofifa.org/flags/46.png       47         63
# 18204  https://cdn.sofifa.org/flags/14.png       47         67
# 18205  https://cdn.sofifa.org/flags/14.png       47         66
# ...

# %%
def defending(data):
    return int(round((data[['Marking',"StandingTackle","SlidingTackle","Interceptions"]].mean()).mean()))
def mental_strong(data):
    return int(round((data[['Aggression',"Vision"]].mean()).mean()))
def power(data):
    return int(round((data[['Stamina',"Strength","ShotPower","Jumping","LongShots"]].mean()).mean()))
def strike(data):
    return int(round((data[['Dribbling',"Finishing","HeadingAccuracy","FKAccuracy","Volleys","Penalties","Composure"]].mean()).mean()))
def keeper(data):
    return int(round((data[['GKDiving',"GKHandling","GKKicking","GKPositioning","GKReflexes"]].mean()).mean()))
def mobility(data):
    return int(round((data[['Acceleration',"SprintSpeed","Agility","Reactions","Balance"]].mean()).mean()))
def passing(data):
    return int(round((data[['ShortPassing',"LongPassing","Crossing"]].mean()).mean()))

# %%
df.rename(columns={"Club Logo": "Club_Logo"},inplace=True)

# %%
df['defending'] = df.apply(defending, axis=1)

# %%
df.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
# ...

# %%
df.tail()
# Out:
#            ID                Name  Age  \
# 18202  238813        J. Lundstram   19
# 18203  243165  N. Christoffersson   19
# 18204  241638           B. Worman   16
# 18205  246268      D. Walker-Rice   17
# 18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 18202  https://cdn.sofifa.org/players/4/19/238813.png     England
# 18203  https://cdn.sofifa.org/players/4/19/243165.png      Sweden
# 18204  https://cdn.sofifa.org/players/4/19/241638.png     England
# 18205  https://cdn.sofifa.org/players/4/19/246268.png     England
# 18206  https://cdn.sofifa.org/players/4/19/246269.png     England
#
#                                       Flag  Overall  Potential  \
# 18202  https://cdn.sofifa.org/flags/14.png       47         65
# 18203  https://cdn.sofifa.org/flags/46.png       47         63
# 18204  https://cdn.sofifa.org/flags/14.png       47         67
# 18205  https://cdn.sofifa.org/flags/14.png       47         66
# ...

# %%
df['mental_strong'] = df.apply(mental_strong, axis=1)
df['power'] = df.apply(power, axis=1)
df['strike'] = df.apply(strike, axis=1)
df['keeper'] =df.apply(keeper, axis=1)
df['mobility'] = df.apply(mobility, axis=1)
df['passing'] = df.apply(passing, axis=1)

# %%
df.shape
# Out:
# (18207, 95)

# %%
df.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
# ...

# %%
df.tail()
# Out:
#            ID                Name  Age  \
# 18202  238813        J. Lundstram   19
# 18203  243165  N. Christoffersson   19
# 18204  241638           B. Worman   16
# 18205  246268      D. Walker-Rice   17
# 18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 18202  https://cdn.sofifa.org/players/4/19/238813.png     England
# 18203  https://cdn.sofifa.org/players/4/19/243165.png      Sweden
# 18204  https://cdn.sofifa.org/players/4/19/241638.png     England
# 18205  https://cdn.sofifa.org/players/4/19/246268.png     England
# 18206  https://cdn.sofifa.org/players/4/19/246269.png     England
#
#                                       Flag  Overall  Potential  \
# 18202  https://cdn.sofifa.org/flags/14.png       47         65
# 18203  https://cdn.sofifa.org/flags/46.png       47         63
# 18204  https://cdn.sofifa.org/flags/14.png       47         67
# 18205  https://cdn.sofifa.org/flags/14.png       47         66
# ...

# %%
players = df[["Name","Age","Overall","Club","defending","mental_strong","power","strike","keeper","mobility","passing"]]

# %%
players.head()
# Out:
#                 Name  Age  Overall                 Club  defending  \
# 0           L. Messi   31       94         FC Barcelona         27
# 1  Cristiano Ronaldo   33       94             Juventus         28
# 2          Neymar Jr   26       92  Paris Saint-Germain         30
# 3             De Gea   27       91    Manchester United         20
# 4       K. De Bruyne   27       91      Manchester City         60
#
#    mental_strong  power  strike  keeper  mobility  passing
# 0             71     76      88      11        92       87
# 1             72     90      88      12        87       81
# 2             72     71      84      12        92       80
# 3             53     43      27      89        62       39
# 4             85     82      79      11        80       92

# %%
players.tail()
# Out:
#                      Name  Age  Overall              Club  defending  \
# 18202        J. Lundstram   19       47   Crewe Alexandra         45
# 18203  N. Christoffersson   19       47    Trelleborgs FF         18
# 18204           B. Worman   16       47  Cambridge United         18
# 18205      D. Walker-Rice   17       47   Tranmere Rovers         24
# 18206           G. Nugent   16       46   Tranmere Rovers         44
#
#        mental_strong  power  strike  keeper  mobility  passing
# 18202             49     45      38       9        59       43
# 18203             40     48      41       9        42       30
# 18204             38     47      42       8        59       30
# 18205             40     46      44      10        53       39
# 18206             52     49      38      11        56       44

# %%
plt.figure(figsize=(20,15))
plt.style.use("fivethirtyeight")
ax = sns.countplot("strike", data=players, palette='dark')
ax.set_xlabel(xlabel="Different stike in football",fontsize=14)
ax.set_ylabel(ylabel="Counts of players",fontsize=14)
ax.set_title(label="Comparison of the striking rate of players",fontsize=16)
plt.show()
# Out:
# E:\programs1\python datamining1\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(20,15))
plt.style.use("fivethirtyeight")
ax = sns.countplot("defending", data=players, palette='dark')
ax.set_xlabel(xlabel="Different stike in football",fontsize=14)
ax.set_ylabel(ylabel="Counts of players",fontsize=14)
ax.set_title(label="Comparison of the striking rate of players",fontsize=16)
plt.show()
# Out:
# E:\programs1\python datamining1\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(20,15))
plt.style.use("fivethirtyeight")
ax = sns.countplot("defending", data=players.head(10), palette='dark')
ax.set_xlabel(xlabel="Different stike in football",fontsize=14)
ax.set_ylabel(ylabel="Counts of players",fontsize=14)
ax.set_title(label="Comparison of the striking rate of players",fontsize=16)
plt.show()
# Out:
# E:\programs1\python datamining1\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(20,15))
plt.style.use("fivethirtyeight")
ax = sns.countplot("mental_strong", data=players, palette='dark')
ax.set_xlabel(xlabel="Different stike in football",fontsize=14)
ax.set_ylabel(ylabel="Counts of players",fontsize=14)
ax.set_title(label="Comparison of the striking rate of players",fontsize=16)
plt.show()
# Out:
# E:\programs1\python datamining1\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(20,15))
plt.style.use("fivethirtyeight")
ax = sns.countplot("mental_strong", data=players.tail(10), palette='dark')
ax.set_xlabel(xlabel="Different stike in football",fontsize=14)
ax.set_ylabel(ylabel="Counts of players",fontsize=14)
ax.set_title(label="Comparison of the striking rate of players",fontsize=16)
plt.show()
# Out:
# E:\programs1\python datamining1\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.rcParams['figure.figsize'] =(15,7)
ax = sns.barplot(x=df['Nationality'].head(50,),y=df['Overall'],  palette='spring')
ax.set_xlabel(xlabel="Countries",fontsize=14)
ax.set_ylabel(ylabel="Overall scores",fontsize=14)
ax.set_title(label="Distribution of overall scores of players from different countries",fontsize=16)
plt.show()

# %%
df['Nationality'].unique()
# Out:
# array(['Argentina', 'Portugal', 'Brazil', 'Spain', 'Belgium', 'Croatia',
#        'Uruguay', 'Slovenia', 'Poland', 'Germany', 'France', 'England',
#        'Italy', 'Egypt', 'Colombia', 'Denmark', 'Gabon', 'Wales',
#        'Senegal', 'Costa Rica', 'Slovakia', 'Netherlands',
#        'Bosnia Herzegovina', 'Morocco', 'Serbia', 'Algeria', 'Austria',
#        'Greece', 'Chile', 'Sweden', 'Korea Republic', 'Finland', 'Guinea',
#        'Montenegro', 'Armenia', 'Switzerland', 'Norway', 'Czech Republic',
#        'Scotland', 'Ghana', 'Central African Rep.', 'DR Congo',
#        'Ivory Coast', 'Russia', 'Ukraine', 'Iceland', 'Mexico', 'Jamaica',
#        'Albania', 'Venezuela', 'Japan', 'Turkey', 'Ecuador', 'Paraguay',
#        'Mali', 'Nigeria', 'Cameroon', 'Dominican Republic', 'Israel',
#        'Kenya', 'Hungary', 'Republic of Ireland', 'Romania',
#        'United States', 'Cape Verde', 'Australia', 'Peru', 'Togo',
# ...

# %%
plt.rcParams['figure.figsize'] =(15,7)
ax = sns.barplot(x=df['Club'].head(30,),y=df['Overall'],  palette='spring')
ax.set_xlabel(xlabel="Club",fontsize=14)
ax.set_ylabel(ylabel="Overall scores",fontsize=14)
ax.set_title(label="Distribution of overall scores of clubs",fontsize=16)
plt.show()

# %%
df.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
# ...

# %%
df.tail()
# Out:
#            ID                Name  Age  \
# 18202  238813        J. Lundstram   19
# 18203  243165  N. Christoffersson   19
# 18204  241638           B. Worman   16
# 18205  246268      D. Walker-Rice   17
# 18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 18202  https://cdn.sofifa.org/players/4/19/238813.png     England
# 18203  https://cdn.sofifa.org/players/4/19/243165.png      Sweden
# 18204  https://cdn.sofifa.org/players/4/19/241638.png     England
# 18205  https://cdn.sofifa.org/players/4/19/246268.png     England
# 18206  https://cdn.sofifa.org/players/4/19/246269.png     England
#
#                                       Flag  Overall  Potential  \
# 18202  https://cdn.sofifa.org/flags/14.png       47         65
# 18203  https://cdn.sofifa.org/flags/46.png       47         63
# 18204  https://cdn.sofifa.org/flags/14.png       47         67
# 18205  https://cdn.sofifa.org/flags/14.png       47         66
# ...

# %%
sns.lmplot(x="Volleys", y="Dribbling",data = df.head(3000), col="Preferred Foot")
plt.show()

# %%
sns.lmplot(x="BallControl", y="Dribbling",data = df.head(3000), col="Preferred Foot")
plt.show()

# %%
sns.lmplot(x="Acceleration", y="Dribbling",data = df.head(3000), col="Preferred Foot")
plt.show()

# %%
sns.lmplot(x="Aggression", y="Dribbling",data = df.head(3000), col="Preferred Foot")
plt.show()
