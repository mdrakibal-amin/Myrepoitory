# %% [markdown]
# # Visualization-2:

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips.isna()
# Out:
#      total_bill    tip    sex  smoker    day   time   size
# 0         False  False  False   False  False  False  False
# 1         False  False  False   False  False  False  False
# 2         False  False  False   False  False  False  False
# 3         False  False  False   False  False  False  False
# 4         False  False  False   False  False  False  False
# ..          ...    ...    ...     ...    ...    ...    ...
# 239       False  False  False   False  False  False  False
# 240       False  False  False   False  False  False  False
# 241       False  False  False   False  False  False  False
# 242       False  False  False   False  False  False  False
# 243       False  False  False   False  False  False  False
#
# [244 rows x 7 columns]

# %%
tips.isna().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
sns.relplot(x='total_bill', y='tip', data=tips)

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.relplot(x='total_bill',y='tip',data=tips, hue='sex')

# %%
sns.relplot(x='total_bill',y='tip',data=tips, hue='sex',style='smoker')

# %%
tips['smoker'][tips['smoker']=='Yes']
# Out:
# 56     Yes
# 58     Yes
# 60     Yes
# 61     Yes
# 62     Yes
#       ...
# 234    Yes
# 236    Yes
# 237    Yes
# 240    Yes
# 241    Yes
# Name: smoker, Length: 93, dtype: category
# Categories (2, object): ['Yes', 'No']

# %%
tips['smoker'][tips['smoker']=='Yes'].count()
# Out:
# 93

# %%
tips['smoker'][tips['smoker']=='No']
# Out:
# 0      No
# 1      No
# 2      No
# 3      No
# 4      No
#        ..
# 235    No
# 238    No
# 239    No
# 242    No
# 243    No
# Name: smoker, Length: 151, dtype: category
# Categories (2, object): ['Yes', 'No']

# %%
tips['smoker'][tips['smoker']=='No'].count()
# Out:
# 151

# %%
tips['smoker'][(tips['smoker']=='Yes') & (tips['sex']=='Male')].count()
# Out:
# 60

# %%
tips['smoker'][(tips['smoker']=='Yes') & (tips['sex']=='Female')].count()
# Out:
# 33

# %%
tips['smoker'][(tips['smoker']=='No') & (tips['sex']=='Male')].count()
# Out:
# 97

# %%
tips['smoker'][(tips['smoker']=='No') & (tips['sex']=='Female')].count()
# Out:
# 54

# %%
sns.relplot(x='total_bill',y='tip',data=tips, hue='sex',style='smoker',size='size')

# %%
sns.relplot(x='total_bill',y='tip',data=tips, hue='size',col='smoker',col_wrap=3)

# %%
sns.relplot(x='total_bill',y='tip',data=tips, hue='size',col='size',col_wrap=3)

# %%
sns.relplot(x='total_bill',y='tip',data=tips, hue='smoker',col='smoker',col_wrap=2)

# %%
sns.scatterplot(x='total_bill',y='tip',data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.catplot(x='day',y='tip',data=tips)

# %%
sns.catplot(x='day',y='tip',data=tips,kind='swarm')
# Out:
# E:\programs1\python datamining1\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(x='day',y='tip',data=tips,kind='swarm',hue='smoker')
# Out:
# E:\programs1\python datamining1\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(x='day',y='tip',data=tips,kind='swarm',hue='size')
# Out:
# E:\programs1\python datamining1\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(x='day',y='tip',data=tips,kind='swarm',hue='sex')
# Out:
# E:\programs1\python datamining1\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(x='day',y='tip',data=tips,kind='box')

# %%
sns.catplot(x='day',y='tip',data=tips,kind='box',hue='size')

# %%
sns.pairplot(data=tips)

# %%
###pairploat:
#Pair plot is used to understand the best set of features to explain a relationship between
#two variables or to form the most separated clusters. It also helps to form some simple classification models
#by drawing some simple lines or make linear separation in our data-set.

# %%
###catplot:
#catplot shows frequencies (or optionally fractions or percents) of the categories of one, two or three categorical variables.
#The first named variable is innermost on the display; that is, its categories vary fastest. catplot is a wrapper for graph
#hbar (default) or graph bar or graph dot.

# %%
#scatterplot:
#Scatter plots are used to plot data points on a horizontal and a vertical axis in the
#attempt to show how much one variable is affected by another. Each row in the data table is 
#represented by a marker whose 
#position depends on its values in the columns 
#set on the X and Y axes.

# %%
#relplot:
#The one we will use most is relplot() . 
#This is a figure-level function for visualizing statistical relationships using two common approaches: 
 #   scatter plots and 
  #  line plots.
   # relplot() combines a FacetGrid with one of two axes-level functions: scatterplot() (with kind="scatter" ; the default
