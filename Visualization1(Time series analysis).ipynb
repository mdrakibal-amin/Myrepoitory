# %% [markdown]
# # Visualization

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Time Series Analysis

# %%
df = pd.DataFrame(np.random.randn(100), index = pd.date_range('2018-12-10', periods=100), columns=['value'])

# %%
df.head()
# Out:
#                value
# 2018-12-10  0.112134
# 2018-12-11 -0.728992
# 2018-12-12  0.223213
# 2018-12-13  1.256468
# 2018-12-14 -0.767096

# %%
df.tail()
# Out:
#                value
# 2019-03-15  0.526090
# 2019-03-16 -0.143396
# 2019-03-17 -1.624490
# 2019-03-18 -2.523637
# 2019-03-19 -1.316731

# %%
#Line Chart
df.plot()
# Out:
# <AxesSubplot:>

# %%
# bar plot
df.head(15).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.plot()
# Out:
# <AxesSubplot:>

# %%
iris.plot(figsize=(12,8))
# Out:
# <AxesSubplot:>

# %%
iris.plot(kind='bar', figsize=(12,8))
# Out:
# <AxesSubplot:>

# %%
iris.iloc[0]
# Out:
# sepal_length       5.1
# sepal_width        3.5
# petal_length       1.4
# petal_width        0.2
# species         setosa
# Name: 0, dtype: object

# %%
iris.iloc[2]
# Out:
# sepal_length       4.7
# sepal_width        3.2
# petal_length       1.3
# petal_width        0.2
# species         setosa
# Name: 2, dtype: object

# %%
iris.drop('species', axis=1).iloc[0].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.drop('species', axis=1).iloc[0].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
iris.drop('species', axis=1).iloc[0].plot.bar()
# Out:
# <AxesSubplot:>

# %%
iris.drop('species', axis=1).iloc[0].plot.barh()###h->horizontal
# Out:
# <AxesSubplot:>

# %%
iris.drop('species', axis=1).iloc[0].plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
iris['sepal_length'].head(48).plot(kind='bar', figsize=(8,6))
# Out:
# <AxesSubplot:>

# %%
iris['sepal_length'].head(48).plot(kind='hist', figsize=(8,6))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind='hist',bins=100, figsize=(12,8))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind='hist',bins=100, figsize=(12,8), orientation='horizontal')
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
iris.hist(color='blue', alpha=0.1,figsize=(5,5))
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)
